# %% [markdown]
# # Test dash

# %%
import pandas as pd

# %%
csv = pd.read_csv('arbres10percent.csv')

# %%
csv
# Out:
#        IDBASE TYPE EMPLACEMENT   DOMANIALITE     ARRONDISSEMENT  \
# 0      128045            Arbre        Jardin    PARIS 19E ARRDT
# 1      207728            Arbre    Alignement   BOIS DE BOULOGNE
# 2      163942            Arbre     CIMETIERE       VAL-DE-MARNE
# 3      157894            Arbre     CIMETIERE  SEINE-SAINT-DENIS
# 4      156855            Arbre     CIMETIERE     HAUTS-DE-SEINE
# ...       ...              ...           ...                ...
# 2072   247851            Arbre    Alignement    PARIS 16E ARRDT
# 2073  2000135            Arbre    Alignement   BOIS DE BOULOGNE
# 2074   149581            Arbre     CIMETIERE  SEINE-SAINT-DENIS
# 2075   192205            Arbre  PERIPHERIQUE    PARIS 13E ARRDT
# 2076   166747            Arbre     CIMETIERE    PARIS 14E ARRDT
#
#      COMPLEMENT ADRESSE  NUMERO  \
# 0                   NaN     NaN
# 1            lampadaire     NaN
# 2                   NaN     NaN
# 3                   NaN     NaN
# ...
